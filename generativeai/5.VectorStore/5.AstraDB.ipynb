# %% [markdown]
# # Astra DB Vector Store in LangChain
#
# **DataStax Astra DB** is a serverless vector database built on Apache Cassandra.
#
# ### Key Features:
# - Built on Cassandra for enterprise scale and multi-region replication.
# - Native integration with LangChain via `langchain-astradb` package (`AstraDBVectorStore`).
# - High-performance vector search using DataStax Jvector index.

# %% [markdown]
# ### Prerequisites & Setup
#
# Set `ASTRA_DB_API_ENDPOINT` and `ASTRA_DB_APPLICATION_TOKEN` in your `.env` file.
# Get free token and endpoint at: https://astra.datastax.com

# %%
import os
from dotenv import load_dotenv, find_dotenv
from langchain_google_genai import GoogleGenerativeAIEmbeddings
# from langchain_huggingface import HuggingFaceEmbeddings
from langchain_astradb import AstraDBVectorStore
from langchain_core.documents import Document

load_dotenv(find_dotenv())

# 1. Initialize Embeddings
# embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

# 2. Load Astra DB Credentials from environment
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT", "https://your-astra-db.apps.astra.datastax.com")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN", "AstraCS:sample_token")

print("AstraDB imports & embeddings initialized successfully!")

# %% [markdown]
# ### Initializing AstraDBVectorStore & Similarity Search
#
# We construct AstraDBVectorStore and perform similarity search over vector collections.

# %%
# Sample Documents
sample_docs = [
    Document(page_content="Astra DB is a cloud-native vector database built on Apache Cassandra.", metadata={"category": "database"}),
    Document(page_content="LangChain provides native AstraDBVectorStore integration for vector search.", metadata={"category": "framework"}),
    Document(page_content="Google Gemini embedding-001 converts text into 768-dimensional vector representations.", metadata={"category": "embedding"})
]

print(f"Prepared {len(sample_docs)} documents for Astra DB ingestion.")
print("Syntax for AstraDBVectorStore creation:")
print("vector_store = AstraDBVectorStore(embedding=embeddings, collection_name='demo', api_endpoint=ASTRA_DB_API_ENDPOINT, token=ASTRA_DB_APPLICATION_TOKEN)")
